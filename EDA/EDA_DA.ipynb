# %% [markdown]
# Proyecto Individual Nº 2

# %% [markdown]
# # Telecomunicaciones

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Importar Librería

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Personalizo el diseño y color de los gráficos

# %%
# Definir la paleta de colores
custom_palette = ["#7f0000","#772800","#6b3d00","#5d4c00","#4f5800","#3f631b","#2e6c36","#177351","#007a69","#007f7f"]

# Configurar seaborn para usar la paleta personalizada
sns.set_palette(custom_palette)

# Configurar estilo y contexto para asegurar consistencia en todos los gráficos
sns.set_style("whitegrid")
sns.set_context("talk")

# %%
# Cargar los archivos CSV en DataFrames
import pandas as pd

# Cargar los datos
acc_por_tecnologia = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Accesos Por Tecnología.csv')
acc_por_velocidad = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Accesos por velocidad.csv')
acc_tecnologia_localidad = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Accesos_tecnologia_localidad.csv')
dial_baf = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Dial-BAf.csv')
ingresos = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Ingresos.csv')
penetracion_hogares = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Penetracion-hogares.csv')
penetracion_poblacion = pd.read_csv(r'C:\Users\claud\OneDrive\Escritorio\Henry_PI_DA\HENRY_PI2_Data_Analytics\ETL\csv_normalizado\Penetración-poblacion.csv')

# Mostrar las primeras filas de cada DataFrame para una exploración inicial
dataframes = {
    "Accesos Por Tecnología": acc_por_tecnologia.head(),
    "Accesos por Velocidad": acc_por_velocidad.head(),
    "Accesos Tecnología Localidad": acc_tecnologia_localidad.head(),
    "Dial BAF": dial_baf.head(),
    "Ingresos": ingresos.head(),
    "Penetración Hogares": penetracion_hogares.head(),
    "Penetración Población": penetracion_poblacion.head()
}

dataframes
# Out:
# {'Accesos Por Tecnología':     Año Trimestre                        Provincia    ADSL  Cablemodem  \
#  0  2024         1                     Buenos Aires  203297     2790663
#  1  2024         1  Ciudad Autónoma de Buenos Aires   70108     1177475
#  2  2024         1                        Catamarca    5901       11025
#  3  2024         1                            Chaco   11343       58929
#  4  2024         1                           Chubut   26306       77217
#
#     Fibra óptica  Wireless   Otros    Total  Código INDEC_x  Código INDEC_y
#  0       1799013    150290  101294  5044557             6.0             6.0
#  1        203756      4493   48879  1504711             2.0             NaN
#  2         56542      1384      81    74933            10.0            10.0
#  3         64463      8404   12404   155543            22.0            22.0
#  4         26356     30867    9930   170676            26.0            26.0  ,
# ...

# %% [markdown]
# Promedio de Accesos por cada 100 hogares

# %%
# Ajustar el tamaño de las fuentes
plt.figure(figsize=(10, 6))
sns.barplot(x="Provincia", y="Accesos por cada 100 hogares", data=penetracion_hogares)
plt.xticks(rotation=90, fontsize=10)  # Ajustar el tamaño de la fuente de las etiquetas del eje x
plt.yticks(fontsize=10)  # Ajustar el tamaño de la fuente de las etiquetas del eje y
plt.title("Promedio de Accesos por cada 100 Hogares", fontsize=14)  # Ajustar el tamaño de la fuente del título
plt.xlabel("Provincia", fontsize=12)  # Ajustar el tamaño de la fuente de la etiqueta del eje x
plt.ylabel("Accesos por cada 100 Hogares", fontsize=12)  # Ajustar el tamaño de la fuente de la etiqueta del eje y
plt.show()

# %% [markdown]
# Se puede ver una gran disparidad en el acceso a internet por provincia. La Ciudad Autónoma de Buenos Aires lidera con más de 100 accesos por cada 100 hogares, mientras que provincias como Chaco, Formosa, y Santiago del Estero tienen menos de 50 accesos.

# %% [markdown]
# La Evolucion de la Tecnologia a lo largo de los años

# %%
# Configurar el estilo y la paleta de colores
sns.set_style("whitegrid")
sns.set_context("talk", font_scale=1)

# Crear el gráfico
plt.figure(figsize=(10, 6))
sns.lineplot(x="Año", y="Accesos", hue="Tecnología", data=acc_por_tecnologia_melted, marker="o", linewidth=2.5)
# Ajustar el título y etiquetas
plt.title("Tecnología Vs el Tiempo", fontsize=16, weight='bold')
plt.xlabel("Año", fontsize=14)
plt.ylabel("Accesos", fontsize=14)
# Ajustar el tamaño de las etiquetas del eje x y y
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Ajustar la leyenda
plt.legend(title="Tecnología", title_fontsize='13', fontsize='12', loc='upper left', frameon=True)
# Mostrar el gráfico
plt.tight_layout()  # Ajustar automáticamente los márgenes para que no se corten elementos
plt.show()

# %% [markdown]
# La evolución de diferentes tecnologías desde 2014 hasta 2024. Se observa un crecimiento en el uso de Fibra Óptica, que supera a las demás tecnologías en los últimos años, reflejando una tendencia hacia conexiones más rápidas y estables. En contraste, ADSL y Cablemodem, aunque muy comunes al inicio del período, muestran un estancamiento o descenso en su adopción. Tecnologías como Wireless y otros medios se mantienen con menor participación en el mercado. Este cambio muestra la preferencia creciente por tecnologías más avanzadas y eficientes.

# %% [markdown]
# Acceso por Tecnología

# %%
# Configurar el estilo y la paleta de colores
sns.set_style("whitegrid")

# Crear el gráfico de Strip Plot
plt.figure(figsize=(10, 6))
sns.stripplot(x="Tecnología", y="Accesos", data=acc_por_tecnologia_melted, jitter=True, size=5, color='brown')

# Título y etiquetas del gráfico
plt.title("Distribución de Accesos por Tecnología", fontsize=14)
plt.xlabel("Tecnología", fontsize=12)
plt.ylabel("Accesos (Escala Logarítmica)", fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Acá vemos la distribución de accesos a internet por tecnología en una escala logarítmica. Cablemodem y Fibra Óptica son las tecnologías con mayor variabilidad y número de accesos, destacándose como las opciones más utilizadas. En contraste, Wireless y otros tienen una distribución mucho más concentrada y con menor cantidad de accesos. Vemos cómo las tecnologías más avanzadas han captado una mayor parte del mercado, mientras que las opciones menos robustas tienen un uso más limitado.

# %% [markdown]
# Total de Accesos Vs los accesos de ADSL, como las nuevas tecnologías avanzan

# %%
# Gráfico de dispersión entre el Total de accesos y ADSL
plt.figure(figsize=(10, 6))  # Ajusté el tamaño de la figura para mejor visualización
sns.scatterplot(x="Total", y="ADSL", data=acc_por_tecnologia)  # Ejemplo usando ADSL como variable Y
# Ajustes de texto
plt.title("Total de Accesos Vs los Accesos de ADSL", fontsize=16)
plt.xlabel("Total de Accesos", fontsize=14)
plt.ylabel("Accesos de ADSL", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Mostrar gráfico
plt.show()

# %% [markdown]
# Podemos ver la relación entre el Total de Accesos a Internet y los Accesos a través de ADSL. Se observa una tendencia decreciente, donde a medida que aumenta el total de accesos, los accesos por ADSL disminuyen. Esto indica un desplazamiento del uso de ADSL hacia otras tecnologías más modernas y eficientes, reflejando la transición tecnológica en el acceso a internet en Argentina.

# %% [markdown]
# Cablemodem Vs Fibra Optica

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x="Cablemodem", y="Fibra óptica", data=acc_por_tecnologia)
plt.title("Relación entre Accesos por Cablemodem y Fibra óptica")
plt.xlabel("Accesos de Cablemodem")
plt.ylabel("Accesos de Fibra óptica")
plt.show()

# %% [markdown]
# Se ve la relación entre los accesos por Cablemodem y Fibra Óptica. Se observa una correlación positiva: a medida que aumentan los accesos por Cablemodem, también crecen los accesos por Fibra Óptica. Sin embargo, en los niveles más altos de accesos, la Fibra Óptica parece ganar terreno, sugiriendo una preferencia por esta tecnología más avanzada. Esto podría reflejar una migración gradual de los usuarios de Cablemodem hacia Fibra Óptica.

# %% [markdown]
# Tecnologías de Acceso

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))
# Crear la matriz de correlación
corr = acc_por_tecnologia[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros', 'Total']].corr()
# Crear el heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", annot_kws={"size": 12})
# Ajustar el título y las etiquetas
plt.title("Matriz de Correlación entre Tecnologías de Acceso", fontsize=16)
plt.xticks(fontsize=12, rotation=45, ha='right')
plt.yticks(fontsize=12, rotation=0)
plt.show()

# %% [markdown]
# La matriz de correlación muestra que Cablemodem y Fibra Óptica están fuertemente correlacionadas con el total de accesos a internet, indicando su importancia en la penetración del servicio. En contraste, ADSL tiene menor correlación con tecnologías más modernas, sugiriendo su declive frente a opciones más avanzadas.

# %% [markdown]
# Disribución y Outliers en Tecnología

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=acc_por_tecnologia[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros']], palette="muted")

# Ajustes de texto
plt.title("Distribución y Outliers en Tecnologías de Acceso", fontsize=16)
plt.ylabel("Accesos", fontsize=14)
plt.xlabel("Tecnologías", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Mostrar gráfico
plt.show()

# %% [markdown]
# Se puede ver la distribución y presencia de outliers en diferentes tecnologías de acceso a internet. Cablemodem y Fibra Óptica presentan una amplia distribución, con varios valores atípicos en niveles altos de accesos, reflejando su popularidad y variabilidad. ADSL tiene una distribución más concentrada, aunque aún muestra algunos outliers. Wireless y otros tienen una distribución limitada, indicando un menor uso y menor variabilidad en su adopción.

# %% [markdown]
# Top 10 mayor acceso a Internet

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Localidad", y="Total general", data=top_localidades, color="#8B0000", edgecolor="black")
plt.title("Top 10 Localidades con Mayor Acceso a Internet", fontsize=16)
plt.xlabel("Localidad", fontsize=12)
plt.ylabel("Total de Accesos", fontsize=12)
plt.xticks(rotation=30, ha="right", fontsize=10)
plt.yticks(fontsize=10)

# Agregar los valores sobre las barras
for index, value in enumerate(top_localidades["Total general"]):
    plt.text(index, value + 10000, f'{value:,}', ha='center', fontsize=10, color="black")

plt.show()

# %% [markdown]
# Este es el Top 10 Localidades con Mayor Acceso a Internet en Argentina. La Ciudad Autónoma de Buenos Aires se destaca con un acceso significativamente superior, superando los 1.5 millones de accesos, seguida por Córdoba y Rosario, aunque con cifras mucho menores. Esto indica una fuerte concentración del acceso a internet en las principales ciudades del país, con una marcada diferencia entre Buenos Aires y el resto de las localidades.

# %% [markdown]
# Top 20 de localidades con mayor acceso a Fibra Optica

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Localidad", y="FIBRA OPTICA", data=top_localidades, color="#8B0000", edgecolor="black")
plt.title("Top 20 Localidades con Mayor Acceso de Fibra Óptica", fontsize=16)
plt.xlabel("Localidad", fontsize=12)
plt.ylabel("Accesos de Fibra Óptica", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(fontsize=10)

# Agregar los valores sobre las barras
for index, value in enumerate(top_localidades["FIBRA OPTICA"]):
    plt.text(index, value + 5000, f'{value:,}', ha='center', fontsize=10, color="black")

plt.show()

# %% [markdown]
# Este es el Top 20 Localidades con Mayor Acceso de Fibra Óptica en Argentina. Córdoba lidera con más de 280,000 accesos, seguida por la Ciudad Autónoma de Buenos Aires y Rosario. Esto destaca la predominancia de estas ciudades en la adopción de tecnología de fibra óptica, lo que sugiere un avance significativo en la modernización de la infraestructura de internet en estas áreas. Localidades como La Plata y Mar del Plata también muestran cifras relevantes, aunque bastante por debajo de los líderes.

# %% [markdown]
# Correlación entre Tecnologías por Localidades

# %%
# Calcular la matriz de correlación
corr = tecnologias_localidad_numeric.corr()

# Configurar la figura y los parámetros del gráfico
plt.figure(figsize=(8, 6))  # Aumentar el tamaño de la figura
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", cbar_kws={'shrink': 0.8}, annot_kws={"size": 10})

# Ajustar título y etiquetas
plt.title("Matriz de Correlación entre Tecnologías de Acceso por Localidad", fontsize=18)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout(pad=1.0)  # Ajustar los márgenes para evitar solapamiento

plt.show()

# %% [markdown]
# La matriz de correlación entre tecnologías de acceso por localidad muestra las relaciones entre diferentes formas de conexión a internet. Cablemodem y ADSL presentan una alta correlación, lo que sugiere que suelen coexistir en las mismas áreas. Dial-Up también muestra una correlación fuerte con estas tecnologías, aunque en menor medida. Fibra Óptica tiene una correlación moderada con Cablemodem y ADSL, indicando que aunque está presente, no necesariamente reemplaza a estas tecnologías en todas las localidades. Tecnologías como WiMAX y Satélite muestran correlaciones bajas o nulas con las demás, lo que indica un uso más aislado o en nichos específicos.
